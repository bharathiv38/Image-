# %% [raw]
# Importing libraries

# %%
from selenium import webdriver
import pandas as pd
import os

# %%
driver = webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# <ipython-input-13-75e8ed774e5c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\Laptop\Downloads\chromedriver_win32\chromedriver.exe")

# %%
my_page = driver.get('https://www.amazon.in/s?k=sarees+for+women&i=apparel&crid=3MRBHQBCDYQLL&sprefix=-%09Sarees%2Caps%2C286&ref=nb_sb_ss_ts-da-p_3_6')

# %%
def make_directory(dirname):
    current_path = os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
make_directory('sareeImage')

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-19-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
print(len(images))
# Out:
# 60

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/81o6gBl-6tL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/817usMDs-bL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81QDnoz1ObL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81b7-oVSXML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91ZZGCp6tuL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81XKaSKvlyL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/713f+6CnyNL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91dDMDg+QTL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71u7TecG7gS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/912JFM8XEJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Lwz9gb6JL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91BywgJ3SKS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61fY+wiG9iL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51vYiIZIIPL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71DLhI+syxL._AC_UL320_.jpg
# ...

# %%
len(urls)
# Out:
# 60

# %%
import shutil
import requests

# %%
page=1
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 1'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-26-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-27-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 0

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)

# %%
page=2
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 2'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
page=2
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 2'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-32-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-33-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 60

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/91E1-tkoNeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91jJXV6eVXL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71jPvKQHw5L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/414ZTVylwlL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/610SrEgE6cL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91tBRnyV4NL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81cvDgHEDmL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/A1kDVUVa08L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/715NYXDhD-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91KPk+N377L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81aaDUrREUS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/918ndrFxlcL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91y1hCZPoCL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71VyoTQm1+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91yS1Ea+WOL._AC_UL320_.jpg
# ...

# %%
page=3
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 3'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-37-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-38-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 0

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)

# %%
page=4
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 4'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-42-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-43-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 53

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71Z28RC9NCL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/817uSyP4+vL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/918fEi3Bq1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/5165O4xRw+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81y6rB1QhiL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91aIn0qLLTL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81lJxlOKNML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/31e9a82bttL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81XUtWnLbsL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/913YM0Gzz9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/A11e0yUX9IL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/712j-h6IF6S._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Pxmepi-mL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71czsNIeBZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51ZAQJbkPFL._AC_UL320_.jpg
# ...

# %%
page=5
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 5'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('sareesImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
my_page=driver.get('https://www.amazon.in/s?k=trousers+for+men&i=apparel&bbn=1571272031&rh=n%3A1571271031%2Cn%3A1968024031&dc&crid=8BC16K4VVFDU&qid=1609173119&rnid=1571272031&sprefix=-%09Trousers%2Caps%2C284&ref=sr_nr_n_2')

# %%
make_directory('trousersImage')

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-50-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
print(len(images))
images[0]
# Out:
# 60
# <selenium.webdriver.remote.webelement.WebElement (session="3cc8eaa7e525d705567dd89eb2984f2a", element="bead5151-7853-4313-8abb-d9a5742e6dbb")>

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71eihq0wyJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71mFpqsS0hL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81aLEvSqU+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71hLZEKJ1wL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81aKPu-Gl-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Lg1x1O29L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71dvIDrJkVL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71x8rLs9PZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/812Bn+j5sOL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71zLO45349L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/5161bTnHVeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71u47o-yKnL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71hNkE28fqL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61nLJ+MDbWL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61MKt9BjsGL._AC_UL320_.jpg
# ...

# %%
page=1
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 1'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('trousersImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-54-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-55-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 10

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71p+y8xHJFL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71x8rLs9PZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71O+nyR4eWL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71gEn8h12yL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71+GDCx9OSL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/712ycacyqxS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81lszaRtoML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71+l67YMMyL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61T6Q6We-nL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71ju3eav-CL._AC_UL320_.jpg

# %%
page=2
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 2'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('trousersImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-59-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-60-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/81d37fLAwUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71x8rLs9PZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71TL5-r7gNL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81UHPautTKS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/5186hQxJJ-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81QjFTCz42L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Yl9fd5euL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71oCU+f9+yL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71Ij9lUVewL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71a4s7Z+55L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/616Z9g4jlIL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91C0KCeTgSL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/7149bSNNU4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61l4fiYfV4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/716+xlyYEpL._AC_UL320_.jpg
# ...

# %%
page=3
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 3'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('trousersImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-63-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-64-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71dUvOr7s9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71UtKK-GVwL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51GPPdnaZCL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61e8uaiWRxL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/5186hQxJJ-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/911BdsQ0AeS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71dhvFUSJEL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51pTmEs9s-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81nCZ-P47lL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81S5-SFyQ2L._AC_UL320_.jpg

# %%
page=4
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 4'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('trousersImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-67-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-68-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71dq1l3u+9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81luI6T+K9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81V+cLWewjL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81TOSynnYxL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61461VVESEL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/815V-iI5xUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61lOWJK2cQS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61jqzS5dwnL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71xula1Sq2L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81QsKldDUiL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51iYflosL-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71guDSklbjL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81BELHzTpML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61LmINWyIgL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51Mxap6AhIL._AC_UL320_.jpg
# ...

# %%
page=5
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 5'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('trousersImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
my_page=driver.get('https://www.amazon.in/s?k=Jeans+for+men&rh=n%3A1968024031&ref=nb_sb_noss')

# %%
make_directory('jeansImage')

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-73-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
len(images)
# Out:
# 60

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/81Op5HUd+1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/812iKBU56QL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81rcMJm4kFL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81m75ojT-1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/613ybn1m+EL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61Don-d8JfL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61TwfPRLhrL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/611hFiiUv4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/712ZqjwyCjL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71m0W58-zQL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81L5daqoXhL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91fdy2SpSvL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81J2xIgSRjL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71DqUzzkb0L._AC_UL320_.jpg
# ...

# %%
page=1
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 1'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('jeansImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-77-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-78-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/812kHdYpQhL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Op5HUd+1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81m75ojT-1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71sQYd4i7HS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51PAjY776nL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51sqbNfjT5L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91mXH+SEo7L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61KIFPR7axL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71IhhpEAo9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/818mVaVBE7L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/714EXTMcpuL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61N1hOGfVLL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71jAfn3Q+QL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61+nyy9oqDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61YB0H8a3gL._AC_UL320_.jpg
# ...

# %%
page=2
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 2'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('jeansImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-81-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-82-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)

# %%
page=3
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 3'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('jeansImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-85-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-86-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/71TdkbI3IZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Gp3corcAL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81wCeJSp4wL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81eM4VHt-3L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71ym-S4TuLL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71tofDe1MZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/616AayUrAbL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51nNXLWlojL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Gg8RZrSbL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/31130Ux2d1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61bya74GM8L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91+tVyTjomL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61l30oARwIL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81GCAx7bXzL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81BlfTrqEDL._AC_UL320_.jpg
# ...

# %%
page=4
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 4'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('jeansImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()
# Out:
# <ipython-input-93-484fa7730e53>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page=driver.find_element_by_xpath("//li[@class='a-last']//a").click()

# %%
images=driver.find_elements_by_xpath("//img[@class='s-image']")
# Out:
# <ipython-input-94-6aef094084de>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images=driver.find_elements_by_xpath("//img[@class='s-image']")

# %%
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
    print(source)
# Out:
# https://m.media-amazon.com/images/I/812kHdYpQhL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81D075zJQSS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/41OXSXHsroL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71E0l9QUTtL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61cNjjtuFML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/918VbKElzyS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81e3bzqfQrS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81IxtDT2sFL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71qwNVhG2PL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81sYj2jTUUL._AC_UL320_.jpg

# %%
page=5
for index,link in enumerate(urls):
    print('Downloading {0} of {1} images from page 5'.format(index+1,len(urls)))
    response=requests.get(link)
    with open('jeansImage/img_{0}{1}.jpeg'.format(index,page),'wb')as file:
        file.write(response.content)

# %%
import os
# Directory with our training sareesImage pictures
train_sareesImage_dir = os.path.join(r'C:\Users\Laptop\sareesImage')

# %%
# Directory with our training trousersImage pictures
train_trousersImage_dir = os.path.join(r'C:\Users\Laptop\trousersImage')

# %%
# Directory with our training jeansImage pictures
train_jeansImage_dir = os.path.join(r'C:\Users\Laptop\jeansImage')

# %%
len(os.listdir(train_sareesImage_dir))
# Out:
# 224

# %%
train_sareesImage_names = os.listdir(train_sareesImage_dir)

# %%
train_trousersImage_names = os.listdir(train_trousersImage_dir)

# %%
train_jeansImage_names = os.listdir(train_jeansImage_dir)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 6
ncols = 6

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_sareesImage_pix = [os.path.join(train_sareesImage_dir, fname) 
                for fname in train_sareesImage_names[pic_index-8:pic_index]]
next_trousersImage_pix = [os.path.join(train_trousersImage_dir, fname) 
                for fname in train_trousersImage_names[pic_index-8:pic_index]]
next_jeansImage_pix = [os.path.join(train_jeansImage_dir, fname) 
                for fname in train_jeansImage_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sareesImage_pix+next_trousersImage_pix+next_jeansImage_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 3 output neuron. 
    tf.keras.layers.Dense(3,activation='softmax')
    
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 298, 298, 16)      448
#
#  max_pooling2d_5 (MaxPooling  (None, 149, 149, 16)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_6 (MaxPooling  (None, 73, 73, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 33, 33, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 512)               1606144
#
# ...

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['acc'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        'C:/Users/Laptop/jeansImage', # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=128,
        class_mode='categorical')
# Out:
# Found 0 images belonging to 0 classes.

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=6,  
      epochs=15,
      verbose=2)
# Out:
# <ipython-input-226-6970e6c11472>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-226-6970e6c11472> in <module>
# ----> 1 history = model.fit_generator(
#       2       train_generator,
#       3       steps_per_epoch=6,
#       4       epochs=15,
#       5       verbose=2)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2014         'Please use `Model.fit`, which supports generators.',
#    2015         stacklevel=2)
# -> 2016     return self.fit(
# ...

# %%
plt.plot(history.history['acc'],c='k',lw=2)
plt.grid(True)
plt.title("Training accuracy with epochs\n",fontsize=18)
plt.xlabel("Training epochs",fontsize=15)
plt.ylabel("Training accuracy",fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-227-e37e5c96f89e> in <module>
# ----> 1 plt.plot(history.history['acc'],c='k',lw=2)
#       2 plt.grid(True)
#       3 plt.title("Training accuracy with epochs\n",fontsize=18)
#       4 plt.xlabel("Training epochs",fontsize=15)
#       5 plt.ylabel("Training accuracy",fontsize=15)
#
# NameError: name 'history' is not defined

# %%
test_datagen = ImageDataGenerator(rescale=1/255)
test_generator = test_datagen.flow_from_directory(
        'C:/Users/himan/sarees_or_trousers_or_jeans',  # This is the source directory for test images
        target_size=(300, 300))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-228-149cdcfc1171> in <module>
#       1 test_datagen = ImageDataGenerator(rescale=1/255)
# ----> 2 test_generator = test_datagen.flow_from_directory(
#       3         'C:/Users/himan/sarees_or_trousers_or_jeans',  # This is the source directory for test images
#       4         target_size=(300, 300))
#
# ~\anaconda3\lib\site-packages\keras\preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     974             and `y` is a numpy array of corresponding labels.
#     975     """
# --> 976     return DirectoryIterator(
#     977         directory,
#     978         self,
#
# ...

# %%
model.evaluate(test_generator,verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-229-eaad9f80e369> in <module>
# ----> 1 model.evaluate(test_generator,verbose=2)
#
# NameError: name 'test_generator' is not defined
